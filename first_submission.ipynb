# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./datasets/train.csv')

# %%
df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# ...

# %%
samplesub = pd.read_csv('./datasets/sample_sub_reg.csv')

# %%
samplesub.head()
# Out:
#    Id    SalePrice
# 0   2  181479.1217
# 1   4  181479.1217
# 2   6  181479.1217
# 3   7  181479.1217
# 4  17  181479.1217

# %%
samplesub.shape
# Out:
# (878, 2)

# %%
testing = pd.read_csv('./datasets/test.csv')

# %%
testing.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# ...

# %%
df['SalePrice'].mean()
# Out:
# 181469.70160897123

# %%
testing['SalePrice'] = df['SalePrice'].mean()

# %%
testing.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0  Grvl       Reg          Lvl  ...            0         0     NaN   NaN
# 1   NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 2   NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 3   NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 4   NaN       IR1          Lvl  ...          185         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type      SalePrice
# ...

# %%
testing.query('`Gr Liv Area` > 4000')
# Out:
#        Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 170  1761  528320050           60        RL         160.0     15623   Pave
# 463  1768  528351010           60        RL         104.0     21535   Pave
#
#     Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC  Fence  \
# 170   NaN       IR1          Lvl  ...            0       555      Ex  MnPrv
# 463   NaN       IR1          Lvl  ...            0         0     NaN    NaN
#
#     Misc Feature Misc Val Mo Sold Yr Sold  Sale Type      SalePrice
# 170          NaN        0       7    2007        WD   181469.701609
# 463          NaN        0       1    2007        WD   181469.701609
#
# [2 rows x 81 columns]

# %%
testing[['Id', 'SalePrice']]
# Out:
#        Id      SalePrice
# 0    2658  181469.701609
# 1    2718  181469.701609
# 2    2414  181469.701609
# 3    1989  181469.701609
# 4     625  181469.701609
# ..    ...            ...
# 873  1662  181469.701609
# 874  1234  181469.701609
# 875  1373  181469.701609
# 876  1672  181469.701609
# 877  1939  181469.701609
#
# [878 rows x 2 columns]

# %%
testing[['Id', 'SalePrice']].to_csv('first_submit.csv', index=False)

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()

# %%
X = df[['Gr Liv Area']]
y = df['SalePrice']

# %%
linreg.fit(X, y)
# Out:
# LinearRegression()

# %%
preds = linreg.predict(testing[['Gr Liv Area']])

# %%
preds
# Out:
# array([228792.19843593, 233097.55624754, 181102.08113799, 122814.15999607,
#        169841.91455375, 136502.98996122, 136613.38375126, 155932.29700852,
#        201414.53850563, 157146.62869898, 150302.21371641, 130762.51287906,
#        167744.43254297, 323620.46408159, 217642.42564173, 163880.64989151,
#        174478.4537355 , 134405.50795043, 211681.16097949, 208258.9534882 ,
#        132970.38867989, 111333.20583175, 194459.72973301, 125022.0357969 ,
#        150412.60750645, 111333.20583175, 207817.37832804, 209142.10380853,
#        132308.02593964,  89916.8105637 , 110670.8430915 , 149308.66960603,
#        307392.57694549, 145996.85590479, 180660.50597782, 176907.11711641,
#        198875.48133467, 126125.97369731, 116411.32017366, 165867.73811226,
#        151074.9702467 , 224155.65925418, 162445.53062097, 166419.70706247,
#        181654.0500882 , 164322.22505168, 213116.28025003, 122482.97862594,
# ...

# %%
testing['SalePrice'] = preds

# %%
testing[['Id', 'SalePrice']].to_csv('second_submit.csv', index=False)
